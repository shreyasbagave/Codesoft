# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("/content/drive/MyDrive/Dataset/Codesoft/advertising.csv")

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.shape
# Out:
# (200, 4)

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %% [markdown]
# Observaion
#
#
#
#
# *   Avg expense spend is highest on tv
# *  avg axpense spend is lowest on Radio
# *  max sale is 27 and min is 1.6

# %%
sns.pairplot(df,x_vars=['TV','Radio','Newspaper'],y_vars='Sales',kind='scatter')

# %%
df['TV'].plot.hist(bins=10,color="blue",xlabel="TV")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Radio'].plot.hist(bins=10,color="purple",xlabel="Radio")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Newspaper'].plot.hist(bins=10,color="green",xlabel="Newspaper")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# The maority sales is the result of low advertising cost in newspaper

# %%
df1=df.drop(columns=["Sales"])
df1.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
x=df1
y=df["Sales"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=2)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test,train_test_split(df[['TV']],df[["Sales"]],test_size=0.3,random_state=0)
# Out:
# (        TV  Radio  Newspaper
#  137  273.7   28.9       59.7
#  163  163.5   36.8        7.4
#  111  241.7   38.0       23.2
#  123  123.1   34.6       12.4
#  109  255.4   26.9        5.5
#  ..     ...    ...        ...
#  43   206.9    8.4       26.4
#  22    13.2   15.9       49.6
#  72    26.8   33.0       19.3
#  15   195.4   47.7       52.9
#  168  215.4   23.6       57.6
#
#  [160 rows x 3 columns],
#          TV  Radio  Newspaper
#  112  175.7   15.4        2.4
#  29    70.6   16.0       40.8
#  182   56.2    5.7       29.7
#  199  232.1    8.6        8.7
#  193  166.8   42.0        3.6
#  85   193.2   18.4       65.7
#  10    66.1    5.8       24.2
#  54   262.7   28.8       15.9
#  115   75.1   35.0       52.7
#  35   290.7    4.1        8.5
#  12    23.8   35.1       65.9
#  92   217.7   33.5       59.0
#  13    97.5    7.6        7.2
#  126    7.8   38.9       50.6
#  174  222.4    3.4       13.1
#  2     17.2   45.9       69.3
#  44    25.1   25.7       43.3
# ...

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (200, 3) (160, 3) (40, 3)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
res=model.predict(x_test)

# %%
plt.plot(res)

# %%
import pickle

# %%
with open ('classifer.pkl')
# Out:
#   File "<ipython-input-26-6f5cf1cfdb32>", line 1
#     with open ('classifer.pkl')
#                                ^
# SyntaxError: expected ':'

# %%
x_train_prediction = model.predict(x_train)

# %%
print(x_train_prediction)
